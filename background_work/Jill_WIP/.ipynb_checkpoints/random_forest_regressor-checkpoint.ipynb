# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import pandas as pd 
import numpy as np
import os
import string
from math import sqrt
from config import u, p

# %%
# Evaluation Metrics
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as rs
from sklearn.metrics import mean_absolute_error as mae

# %%
# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
from psycopg2.extensions import register_adapter, AsIs
def adapt_numpy_int64(numpy_int64):
  return AsIs(numpy_int64)
register_adapter(np.int64, adapt_numpy_int64)

# %% [markdown]
# ## Connect to DB: Create sample data that joins Acocunt Info, Appraisal Data, & Res_Adl

# %%
database_path = f'postgres://{u}:{p}@database1.cpwzlmglu2fg.us-east-2.rds.amazonaws.com/proptax'

# %%
# Create Engine
engine = create_engine(database_path)
conn = engine.connect()

# %%
# The ORM’s “handle” to the database is the Session.
session = Session(engine)

# %% [markdown]
# ### Sample 2019

# %%
query_one = "select ai.account_num, ai.appraisal_yr, aay.tot_val, aay.prev_mkt_val, CASE WHEN aay.tot_val < aay.prev_mkt_val THEN 1 ELSE 0 END as Decrease, \
       street_num, street_half_num, full_street_name, property_city, property_zipcode, nbhd_cd, desirability_rating, bldg_class_cd, tot_living_area_sf, foundation_typ_desc, heating_typ_desc, ac_typ_desc, ext_wall_desc, roof_typ_desc, num_fireplaces, num_kitchens, num_full_baths, num_half_baths, num_wet_bars, num_bedrooms, sprinkler_sys_ind, pool_ind \
        from account_info_2019 as ai \
        INNER JOIN account_apprl_year_2019 as aay on ai.account_num = aay.account_num \
        INNER JOIN res_detail_2019 as rd on aay.account_num = rd.account_num \
        where ai.division_cd = 'RES'\
        and nbhd_cd = '2RSS04'"

res_2019_data = pd.read_sql(query_one, conn).set_index('account_num')

# %% [markdown]
# ## Explore Sample Data

# %%
# 2019
res_2019_data.head(10)
# Out:
#                    appraisal_yr    tot_val  prev_mkt_val  decrease street_num  \
# account_num
# 00000789241000000          2019   772680.0      772680.0         0      10041
# 00000788959000000          2019   371470.0      319570.0         0      10150
# 00000788971000000          2019   506660.0      506660.0         0      10116
# 00000789262000000          2019   897530.0      939210.0         1       9929
# 00000789271000000          2019   459510.0      440000.0         0      10171
# 00000788977000000          2019   420000.0      478320.0         1      10111
# 008083000G0020000          2019  1090850.0     1090850.0         0      10029
# 00000789094000000          2019   426560.0      426560.0         0       9841
# 00000789085000000          2019   539280.0      539280.0         0       9817
# 00808400050220000          2019   917360.0      917360.0         0      10219
#
#                   street_half_num full_street_name property_city  \
# account_num
# 00000789241000000                      CARIBOU TRL        DALLAS
# 00000788959000000                        ESTATE LN        DALLAS
# 00000788971000000                        ESTATE LN        DALLAS
# 00000789262000000                      CARIBOU TRL        DALLAS
# 00000789271000000                        ESTATE LN        DALLAS
# 00000788977000000                    MAPLERIDGE DR        DALLAS
# 008083000G0020000                        ESTATE LN        DALLAS
# 00000789094000000                    LARCHCREST DR        DALLAS
# 00000789085000000                    LARCHCREST DR        DALLAS
# 00808400050220000                        CHURCH RD        DALLAS
#
#                   property_zipcode nbhd_cd    ...    ext_wall_desc  \
# account_num                                   ...
# 00000789241000000        752382128  2RSS04    ...     BRICK VENEER
# 00000788959000000        752382135  2RSS04    ...     BRICK VENEER
# 00000788971000000        752382135  2RSS04    ...     BRICK VENEER
# 00000789262000000        752382126  2RSS04    ...     BRICK VENEER
# 00000789271000000        752382134  2RSS04    ...     BRICK VENEER
# 00000788977000000        752382150  2RSS04    ...     BRICK VENEER
# 008083000G0020000        752382132  2RSS04    ...     BRICK VENEER
# 00000789094000000        752382114  2RSS04    ...     BRICK VENEER
# 00000789085000000        752382114  2RSS04    ...     BRICK VENEER
# 00808400050220000        752381601  2RSS04    ...           STUCCO
#
#                   roof_typ_desc  num_fireplaces num_kitchens num_full_baths  \
# account_num
# 00000789241000000           HIP               1            1              3
# 00000788959000000         GABLE               1            1              2
# 00000788971000000         GABLE               1            1              3
# 00000789262000000           HIP               1            1              4
# 00000789271000000           HIP               1            1              2
# 00000788977000000         GABLE               1            1              3
# 008083000G0020000           HIP               1            1              4
# 00000789094000000         GABLE               1            1              2
# 00000789085000000         GABLE               1            1              4
# 00808400050220000           HIP               1            1              3
#
#                   num_half_baths num_wet_bars num_bedrooms  sprinkler_sys_ind  \
# account_num
# 00000789241000000              1            1            3                  N
# 00000788959000000              1            0            3                  N
# 00000788971000000              0            1            4                  N
# 00000789262000000              0            0            5                  Y
# 00000789271000000              0            0            3                  N
# 00000788977000000              0            0            5                  Y
# 008083000G0020000              1            1            4                  Y
# 00000789094000000              1            0            3                  Y
# 00000789085000000              0            0            3                  N
# 00808400050220000              0            0            4                  Y
#
#                    pool_ind
# account_num
# 00000789241000000         N
# 00000788959000000         N
# 00000788971000000         Y
# 00000789262000000         N
# 00000789271000000         Y
# 00000788977000000         Y
# 008083000G0020000         N
# 00000789094000000         N
# 00000789085000000         Y
# 00808400050220000         Y
#
# [10 rows x 26 columns]

# %%
res_2019_data.shape
# Out:
# (79, 26)

# %%
res_2019_data.columns
# Out:
# Index(['appraisal_yr', 'tot_val', 'prev_mkt_val', 'decrease', 'street_num',
#        'street_half_num', 'full_street_name', 'property_city',
#        'property_zipcode', 'nbhd_cd', 'desirability_rating', 'bldg_class_cd',
#        'tot_living_area_sf', 'foundation_typ_desc', 'heating_typ_desc',
#        'ac_typ_desc', 'ext_wall_desc', 'roof_typ_desc', 'num_fireplaces',
#        'num_kitchens', 'num_full_baths', 'num_half_baths', 'num_wet_bars',
#        'num_bedrooms', 'sprinkler_sys_ind', 'pool_ind'],
#       dtype='object')

# %%
res_2019_data.dtypes
# Out:
# appraisal_yr             int64
# tot_val                float64
# prev_mkt_val           float64
# decrease                 int64
# street_num              object
# street_half_num         object
# full_street_name        object
# property_city           object
# property_zipcode        object
# nbhd_cd                 object
# desirability_rating     object
# bldg_class_cd           object
# tot_living_area_sf       int64
# foundation_typ_desc     object
# heating_typ_desc        object
# ac_typ_desc             object
# ext_wall_desc           object
# roof_typ_desc           object
# num_fireplaces           int64
# num_kitchens             int64
# num_full_baths           int64
# num_half_baths           int64
# num_wet_bars             int64
# num_bedrooms             int64
# sprinkler_sys_ind       object
# pool_ind                object
# dtype: object

# %%
# Plot histogram grid
res_2019_data.hist(figsize=(24,24), xrot=-45) ## Display the labels rotated by 45 degress

# Clear the text "residue"
plt.show()

# %%
# PLot Desirablilty
plt.figure(figsize=(8,8))
sns.countplot(y='desirability_rating', data=res_2019_data)

# %%
# Drop Null Values 
drop_res_2019_data = res_2019_data.dropna(how="all")

# %%
drop_res_2019_data.head()
# Out:
#                    appraisal_yr   tot_val  prev_mkt_val  decrease street_num  \
# account_num
# 00000789241000000          2019  772680.0      772680.0         0      10041
# 00000788959000000          2019  371470.0      319570.0         0      10150
# 00000788971000000          2019  506660.0      506660.0         0      10116
# 00000789262000000          2019  897530.0      939210.0         1       9929
# 00000789271000000          2019  459510.0      440000.0         0      10171
#
#                   street_half_num full_street_name property_city  \
# account_num
# 00000789241000000                      CARIBOU TRL        DALLAS
# 00000788959000000                        ESTATE LN        DALLAS
# 00000788971000000                        ESTATE LN        DALLAS
# 00000789262000000                      CARIBOU TRL        DALLAS
# 00000789271000000                        ESTATE LN        DALLAS
#
#                   property_zipcode nbhd_cd    ...    ext_wall_desc  \
# account_num                                   ...
# 00000789241000000        752382128  2RSS04    ...     BRICK VENEER
# 00000788959000000        752382135  2RSS04    ...     BRICK VENEER
# 00000788971000000        752382135  2RSS04    ...     BRICK VENEER
# 00000789262000000        752382126  2RSS04    ...     BRICK VENEER
# 00000789271000000        752382134  2RSS04    ...     BRICK VENEER
#
#                   roof_typ_desc  num_fireplaces num_kitchens num_full_baths  \
# account_num
# 00000789241000000           HIP               1            1              3
# 00000788959000000         GABLE               1            1              2
# 00000788971000000         GABLE               1            1              3
# 00000789262000000           HIP               1            1              4
# 00000789271000000           HIP               1            1              2
#
#                   num_half_baths num_wet_bars num_bedrooms  sprinkler_sys_ind  \
# account_num
# 00000789241000000              1            1            3                  N
# 00000788959000000              1            0            3                  N
# 00000788971000000              0            1            4                  N
# 00000789262000000              0            0            5                  Y
# 00000789271000000              0            0            3                  N
#
#                    pool_ind
# account_num
# 00000789241000000         N
# 00000788959000000         N
# 00000788971000000         Y
# 00000789262000000         N
# 00000789271000000         Y
#
# [5 rows x 26 columns]

# %%
drop_res_2019_data.loc['00000788983000000']
# Out:
# appraisal_yr                    2019
# tot_val                       750000
# prev_mkt_val                  640280
# decrease                           0
# street_num                     10123
# street_half_num
# full_street_name       MAPLERIDGE DR
# property_city                 DALLAS
# property_zipcode           752382150
# nbhd_cd                       2RSS04
# desirability_rating        VERY GOOD
# bldg_class_cd                     21
# tot_living_area_sf              3183
# foundation_typ_desc    PIER AND BEAM
# heating_typ_desc        CENTRAL FULL
# ac_typ_desc             CENTRAL FULL
# ext_wall_desc           BRICK VENEER
# roof_typ_desc                  GABLE
# num_fireplaces                     1
# num_kitchens                       1
# num_full_baths                     2
# num_half_baths                     2
# num_wet_bars                       0
# num_bedrooms                       4
# sprinkler_sys_ind                  Y
# pool_ind                           N
# Name: 00000788983000000, dtype: object

# %%
plt.figure(figsize=(16,16))
sns.heatmap(drop_res_2019_data.corr())

# %%
# Create a DF using only existing interger columns 
int_df = drop_res_2019_data[['tot_val', 'decrease', 'tot_living_area_sf', 'num_kitchens', 'num_full_baths', 'num_half_baths', 'num_bedrooms']]
int_df.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms
# account_num
# 00000789241000000               3               1             3
# 00000788959000000               2               1             3
# 00000788971000000               3               0             4
# 00000789262000000               4               0             5
# 00000789271000000               2               0             3

# %%
int_df.columns
# Out:
# Index(['tot_val', 'decrease', 'tot_living_area_sf', 'num_kitchens',
#        'num_full_baths', 'num_half_baths', 'num_bedrooms'],
#       dtype='object')

# %%
# Create a DF using only existing object columns 
object_df = drop_res_2019_data[['pool_ind', 'sprinkler_sys_ind', 'foundation_typ_desc', 'heating_typ_desc', 'ac_typ_desc', 'ext_wall_desc', 'roof_typ_desc', 'desirability_rating', 'bldg_class_cd']]
object_df.head()
# Out:
#                   pool_ind sprinkler_sys_ind foundation_typ_desc  \
# account_num
# 00000789241000000        N                 N       PIER AND BEAM
# 00000788959000000        N                 N       PIER AND BEAM
# 00000788971000000        Y                 N       PIER AND BEAM
# 00000789262000000        N                 Y                SLAB
# 00000789271000000        Y                 N       PIER AND BEAM
#
#                   heating_typ_desc   ac_typ_desc ext_wall_desc roof_typ_desc  \
# account_num
# 00000789241000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER           HIP
# 00000788959000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER         GABLE
# 00000788971000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER         GABLE
# 00000789262000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER           HIP
# 00000789271000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER           HIP
#
#                   desirability_rating bldg_class_cd
# account_num
# 00000789241000000                GOOD            18
# 00000788959000000             AVERAGE            18
# 00000788971000000                GOOD            18
# 00000789262000000                GOOD            21
# 00000789271000000                GOOD            18

# %%
object_df.columns
# Out:
# Index(['pool_ind', 'sprinkler_sys_ind', 'foundation_typ_desc',
#        'heating_typ_desc', 'ac_typ_desc', 'ext_wall_desc', 'roof_typ_desc',
#        'desirability_rating', 'bldg_class_cd'],
#       dtype='object')

# %% [markdown]
# ### Get Dummies

# %%
# Dummify object dataframe 
dummy_df = pd.get_dummies(object_df)
dummy_df.head()
# Out:
#                    pool_ind_N  pool_ind_Y  sprinkler_sys_ind_N  \
# account_num
# 00000789241000000           1           0                    1
# 00000788959000000           1           0                    1
# 00000788971000000           0           1                    1
# 00000789262000000           1           0                    0
# 00000789271000000           0           1                    1
#
#                    sprinkler_sys_ind_Y  foundation_typ_desc_PIER AND BEAM  \
# account_num
# 00000789241000000                    0                                  1
# 00000788959000000                    0                                  1
# 00000788971000000                    0                                  1
# 00000789262000000                    1                                  0
# 00000789271000000                    0                                  1
#
#                    foundation_typ_desc_SLAB  heating_typ_desc_CENTRAL FULL  \
# account_num
# 00000789241000000                         0                              1
# 00000788959000000                         0                              1
# 00000788971000000                         0                              1
# 00000789262000000                         1                              1
# 00000789271000000                         0                              1
#
#                    ac_typ_desc_CENTRAL FULL  ac_typ_desc_UNASSIGNED  \
# account_num
# 00000789241000000                         1                       0
# 00000788959000000                         1                       0
# 00000788971000000                         1                       0
# 00000789262000000                         1                       0
# 00000789271000000                         1                       0
#
#                    ext_wall_desc_BRICK VENEER        ...         \
# account_num                                          ...
# 00000789241000000                           1        ...
# 00000788959000000                           1        ...
# 00000788971000000                           1        ...
# 00000789262000000                           1        ...
# 00000789271000000                           1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 24 columns]

# %%
dummy_df.columns
# Out:
# Index(['pool_ind_N', 'pool_ind_Y', 'sprinkler_sys_ind_N',
#        'sprinkler_sys_ind_Y', 'foundation_typ_desc_PIER AND BEAM',
#        'foundation_typ_desc_SLAB', 'heating_typ_desc_CENTRAL FULL',
#        'ac_typ_desc_CENTRAL FULL', 'ac_typ_desc_UNASSIGNED',
#        'ext_wall_desc_BRICK VENEER', 'ext_wall_desc_FRAME',
#        'ext_wall_desc_STONE VENEER', 'ext_wall_desc_STUCCO',
#        'roof_typ_desc_GABLE', 'roof_typ_desc_HIP', 'roof_typ_desc_MANSARD',
#        'desirability_rating_AVERAGE', 'desirability_rating_EXCELLENT',
#        'desirability_rating_FAIR', 'desirability_rating_GOOD',
#        'desirability_rating_VERY GOOD', 'bldg_class_cd_18', 'bldg_class_cd_21',
#        'bldg_class_cd_23'],
#       dtype='object')

# %%
#dummy_df.dtypes #takes forever on the full dataset

# %% [markdown]
# ### Create the Clean DF by merging int_df and dummy_df

# %%
clean_df = pd.merge(int_df, dummy_df, right_index=True, left_index=True, how="inner")
clean_df.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
clean_df.describe()
# Out:
#             tot_val   decrease  tot_living_area_sf  num_kitchens  \
# count  7.900000e+01  79.000000           79.000000          79.0
# mean   5.968192e+05   0.126582         3316.303797           1.0
# std    1.893782e+05   0.334629          757.089643           0.0
# min    3.510600e+05   0.000000         1622.000000           1.0
# 25%    4.419700e+05   0.000000         2752.000000           1.0
# 50%    5.392800e+05   0.000000         3353.000000           1.0
# 75%    6.956600e+05   0.000000         3771.500000           1.0
# max    1.130000e+06   1.000000         5608.000000           1.0
#
#        num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  pool_ind_Y  \
# count       79.000000       79.000000     79.000000   79.000000   79.000000
# mean         2.962025        0.772152      3.759494    0.582278    0.417722
# std          0.758592        0.598060      0.683415    0.496335    0.496335
# min          2.000000        0.000000      2.000000    0.000000    0.000000
# 25%          2.000000        0.000000      3.000000    0.000000    0.000000
# 50%          3.000000        1.000000      4.000000    1.000000    0.000000
# 75%          4.000000        1.000000      4.000000    1.000000    1.000000
# max          4.000000        2.000000      5.000000    1.000000    1.000000
#
#        sprinkler_sys_ind_N        ...         roof_typ_desc_HIP  \
# count            79.000000        ...                 79.000000
# mean              0.569620        ...                  0.392405
# std               0.498293        ...                  0.491406
# min               0.000000        ...                  0.000000
# 25%               0.000000        ...                  0.000000
# 50%               1.000000        ...                  0.000000
# 75%               1.000000        ...                  1.000000
# max               1.000000        ...                  1.000000
#
#        roof_typ_desc_MANSARD  desirability_rating_AVERAGE  \
# count              79.000000                    79.000000
# mean                0.037975                     0.240506
# std                 0.192356                     0.430122
# min                 0.000000                     0.000000
# 25%                 0.000000                     0.000000
# 50%                 0.000000                     0.000000
# 75%                 0.000000                     0.000000
# max                 1.000000                     1.000000
#
#        desirability_rating_EXCELLENT  desirability_rating_FAIR  \
# count                      79.000000                 79.000000
# mean                        0.126582                  0.012658
# std                         0.334629                  0.112509
# min                         0.000000                  0.000000
# 25%                         0.000000                  0.000000
# 50%                         0.000000                  0.000000
# 75%                         0.000000                  0.000000
# max                         1.000000                  1.000000
#
#        desirability_rating_GOOD  desirability_rating_VERY GOOD  \
# count                 79.000000                      79.000000
# mean                   0.354430                       0.265823
# std                    0.481397                       0.444593
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    1.000000                       1.000000
# max                    1.000000                       1.000000
#
#        bldg_class_cd_18  bldg_class_cd_21  bldg_class_cd_23
# count         79.000000         79.000000         79.000000
# mean           0.860759          0.101266          0.037975
# std            0.348409          0.303608          0.192356
# min            0.000000          0.000000          0.000000
# 25%            1.000000          0.000000          0.000000
# 50%            1.000000          0.000000          0.000000
# 75%            1.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000
#
# [8 rows x 31 columns]

# %%
clean_df = clean_df.dropna(how="any")

# %%
clean_df.shape
# Out:
# (79, 31)

# %% [markdown]
# ### Create Dataframes to use with models

# %%
# Dataframe for Logistic Regression
df_logic_reg = clean_df
df_logic_reg.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
df_logic_reg.columns
# Out:
# Index(['tot_val', 'decrease', 'tot_living_area_sf', 'num_kitchens',
#        'num_full_baths', 'num_half_baths', 'num_bedrooms', 'pool_ind_N',
#        'pool_ind_Y', 'sprinkler_sys_ind_N', 'sprinkler_sys_ind_Y',
#        'foundation_typ_desc_PIER AND BEAM', 'foundation_typ_desc_SLAB',
#        'heating_typ_desc_CENTRAL FULL', 'ac_typ_desc_CENTRAL FULL',
#        'ac_typ_desc_UNASSIGNED', 'ext_wall_desc_BRICK VENEER',
#        'ext_wall_desc_FRAME', 'ext_wall_desc_STONE VENEER',
#        'ext_wall_desc_STUCCO', 'roof_typ_desc_GABLE', 'roof_typ_desc_HIP',
#        'roof_typ_desc_MANSARD', 'desirability_rating_AVERAGE',
#        'desirability_rating_EXCELLENT', 'desirability_rating_FAIR',
#        'desirability_rating_GOOD', 'desirability_rating_VERY GOOD',
#        'bldg_class_cd_18', 'bldg_class_cd_21', 'bldg_class_cd_23'],
#       dtype='object')

# %%
# Dataframe or Decsion Tree and Random Forest
df_trees = clean_df
df_trees.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
# Dataframe for KNN
df_knn = clean_df
df_knn.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
# Dataframe for SVM 
df_svm = clean_df
df_svm.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
df_xg = clean_df
df_xg.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
df_rfr = clean_df
df_rfr.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %% [markdown]
# <h1><center>Machine Learning Models</center></h1>

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# #### Logic Regression with Clean DataFrame

# %%
# Use Clean Sample 2019 Data 
# Predict using SciKit Learn model.predict
# Assign X (data) and y (target)
X = df_logic_reg[['tot_val', 'tot_living_area_sf', 'num_kitchens',
       'num_full_baths', 'num_half_baths', 'num_bedrooms', 'pool_ind_N',
       'pool_ind_Y', 'sprinkler_sys_ind_N', 'sprinkler_sys_ind_Y',
#        'foundation_typ_desc_BLOCK', 'foundation_typ_desc_BRICK',
#        'foundation_typ_desc_FOUNDATION SUPPORT',
#        'foundation_typ_desc_GRADE AND INTERIOR BEAM',
#        'foundation_typ_desc_PIER AND BEAM', 'foundation_typ_desc_POST',
#        'foundation_typ_desc_SLAB', 'foundation_typ_desc_UNASSIGNED',
#        'heating_typ_desc_CENTRAL FULL', 'heating_typ_desc_FLOOR FURNACE',
#        'heating_typ_desc_GAS HEATERS', 'heating_typ_desc_UNASSIGNED',
#        'heating_typ_desc_WALL', 'ac_typ_desc_CENTRAL FULL',
#        'ac_typ_desc_CENTRAL PARTIAL', 'ac_typ_desc_NONE',
#        'ac_typ_desc_UNASSIGNED', 'ac_typ_desc_WINDOW',
#        'ext_wall_desc_ALUMINIUM', 'ext_wall_desc_ASBESTOS SHINGLES',
#        'ext_wall_desc_BRICK VENEER', 'ext_wall_desc_CONCRETE FIBERBOARD',
#        'ext_wall_desc_FRAME', 'ext_wall_desc_SOLID MASONRY',
#        'ext_wall_desc_STONE VENEER', 'ext_wall_desc_STUCCO',
#        'ext_wall_desc_UNASSIGNED', 'ext_wall_desc_VINYL',
#        'ext_wall_desc_WOOD SHINGLES', 'roof_typ_desc_CUTUP, DORMER',
#        'roof_typ_desc_FLAT', 'roof_typ_desc_GABLE', 'roof_typ_desc_GAMBREL',
#        'roof_typ_desc_HIP', 'roof_typ_desc_IRREGULAR', 'roof_typ_desc_MANSARD',
#        'roof_typ_desc_SHED', 'roof_typ_desc_UNASSIGNED',
       'desirability_rating_AVERAGE', 'desirability_rating_EXCELLENT',
       'desirability_rating_FAIR', 'desirability_rating_GOOD',
      # 'desirability_rating_MANUALLY ENTER DEPRECIATION',
      # 'desirability_rating_POOR', 'desirability_rating_UNASSIGNED',
       'desirability_rating_VERY GOOD', 
       #'desirability_rating_VERY POOR',
       #'bldg_class_cd_01', 'bldg_class_cd_02', 'bldg_class_cd_03',
       #'bldg_class_cd_04', 'bldg_class_cd_05', 'bldg_class_cd_06',
       #'bldg_class_cd_07', 'bldg_class_cd_08', 'bldg_class_cd_09',
       #'bldg_class_cd_10', 'bldg_class_cd_12', 'bldg_class_cd_13',
       #'bldg_class_cd_14', 'bldg_class_cd_15', 'bldg_class_cd_16',
       'bldg_class_cd_18', 'bldg_class_cd_21', 'bldg_class_cd_23',
       #'bldg_class_cd_24', 'bldg_class_cd_25', 'bldg_class_cd_26'
       #'bldg_class_cd_CONDOMINIUM', 
       #'bldg_class_cd_LAND ONLY',
       #'bldg_class_cd_TOWNHOME'
                 ]]
y = df_logic_reg["decrease"]
print(X.shape, y.shape)
# Out:
# (79, 18) (79,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X.loc[['00000788983000000']]
# Out:
#                     tot_val  tot_living_area_sf  num_kitchens  num_full_baths  \
# account_num
# 00000788983000000  750000.0                3183             1               2
#
#                    num_half_baths  num_bedrooms  pool_ind_N  pool_ind_Y  \
# account_num
# 00000788983000000               2             4           1           0
#
#                    sprinkler_sys_ind_N  sprinkler_sys_ind_Y  \
# account_num
# 00000788983000000                    0                    1
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000788983000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000788983000000                         0                         0
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000788983000000                              1                 0
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000788983000000                 1                 0

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

# %%
classifier.fit(X_train, y_train)

# %%
# Validate the model using the test data
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")

# %%
# Make predictions
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")

# %%
# Prediction DataFrame 
test_df = pd.DataFrame({"Prediction": predictions, "Actual": y_test})
train_df = pd.DataFrame({"Prediction": classifier.predict(X_train), "Actual": y_train})

# %%
test_df

#test_df.loc['00000788983000000']

# %%
train_df.head()

#train_df.loc['00000788983000000']

# %%
#push predictions to the database
#clear the existing predictions? 
# engine.execute("DROP TABLE public.predictions;")
dfLRPredictions.to_sql('predictions_lr', con=engine, if_exists='replace')
engine.execute("SELECT * FROM predictions_lr LIMIT 1000").fetchall()

# %% [markdown]
# ## Descision Tree & Random Forest

# %%
from sklearn import tree

# %%
target = df_trees["decrease"]
target_names = ["NO", "YES"]

# %%
data = df_trees.drop("decrease", axis=1)
feature_names = data.columns
data.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)

# %%
# Calculate feature importances
importances = rf.feature_importances_

# %%
feature_names = feature_names

# %%
len(importances[indices])

# %%
# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Rearrange feature names so they match the sorted feature importances
names = [feature_names[i] for i in indices]

# Create plot
plt.figure(figsize=(16,16))

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X.shape[0]), len(importances[indices]))

# Add feature names as x-axis labels
plt.xticks(range(X.shape[0]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ## K_Nearest_Neighbors

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
y = df_knn["increase"]
target_names = ["NO", "YES"]

# %%
X = df_knn.drop("increase", axis=1)
X.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()

# %%
# Note that k: 13 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test, y_test))

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
target = df_svm["decrease"]
target_names = ["NO", "YES"]

# %%
data = df_svm.drop("decrease", axis=1)
feature_names = data.columns
data.head()
# Out:
#                     tot_val  tot_living_area_sf  num_kitchens  num_full_baths  \
# account_num
# 00000788959000000  371470.0                1970             1               2
# 00000788971000000  506660.0                3582             1               3
# 00000789271000000  459510.0                2800             1               2
# 00000789262000000  897530.0                3667             1               4
# 00000789241000000  772680.0                3502             1               3
#
#                    num_half_baths  num_bedrooms  pool_ind_N  pool_ind_Y  \
# account_num
# 00000788959000000               1             3           1           0
# 00000788971000000               0             4           0           1
# 00000789271000000               0             3           0           1
# 00000789262000000               0             5           1           0
# 00000789241000000               1             3           1           0
#
#                    sprinkler_sys_ind_N  sprinkler_sys_ind_Y        ...         \
# account_num                                                        ...
# 00000788959000000                    1                    0        ...
# 00000788971000000                    1                    0        ...
# 00000789271000000                    1                    0        ...
# 00000789262000000                    0                    1        ...
# 00000789241000000                    1                    0        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789271000000                  1                      0
# 00000789262000000                  1                      0
# 00000789241000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789271000000                            0                              0
# 00000789262000000                            0                              0
# 00000789241000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789271000000                         0                         1
# 00000789262000000                         0                         1
# 00000789241000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789271000000                              0                 1
# 00000789262000000                              0                 0
# 00000789241000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789271000000                 0                 0
# 00000789262000000                 1                 0
# 00000789241000000                 0                 0
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (79, 30)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=12)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear', probability=True)
model.fit(X_train, y_train)

#faster without probabilites
# model = SVC(kernel='linear')
# not using the rbf kernel type, just for reference
# model = SVC(kernel='rbf')
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.900

# %%
probas = model.predict_proba(X_test)
probas
# Out:
# array([[0.86864868, 0.13135132],
#        [0.88625798, 0.11374202],
#        [0.86867085, 0.13132915],
#        [0.86040474, 0.13959526],
#        [0.86001352, 0.13998648],
#        [0.86957771, 0.13042229],
#        [0.85886577, 0.14113423],
#        [0.85915442, 0.14084558],
#        [0.85744769, 0.14255231],
#        [0.85834619, 0.14165381],
#        [0.86210551, 0.13789449],
#        [0.85814309, 0.14185691],
#        [0.85766426, 0.14233574],
#        [0.85733126, 0.14266874],
#        [0.88834136, 0.11165864],
#        [0.85984701, 0.14015299],
#        [0.86371271, 0.13628729],
#        [0.85805308, 0.14194692],
#        [0.85406373, 0.14593627],
#        [0.86548611, 0.13451389]])

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.90      1.00      0.95        18
#          YES       0.00      0.00      0.00         2
#
#    micro avg       0.90      0.90      0.90        20
#    macro avg       0.45      0.50      0.47        20
# weighted avg       0.81      0.90      0.85        20
# D:\Workspace\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# D:\Workspace\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# D:\Workspace\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
predictions
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'], dtype=object)

# %% [markdown]
# @TODO - Add above predictions array into res_2019_data

# %% [markdown]
# @TODO AUC Chart

# %% [markdown]
# @TODO Percentage of Predcition Confidence using the Predictions array

# %%
probNo = []
probYes = []
for i in probas:
    probNo.append(i[0])
    probYes.append(i[1])

# %%
predictions = model.predict(data)
probas = model.predict_proba(data)
# predictions = np.array(predictions)
res_2019_data['prediction'] = predictions
res_2019_data['probabilityNo'] = probNo
res_2019_data['probabilityYes'] = probYes

# %%
res_2019_data
# Out:
#                    appraisal_yr    tot_val  prev_mkt_val decrease street_num  \
# account_num
# 00000788959000000          2019   371470.0      319570.0       No      10150
# 00000788971000000          2019   506660.0      506660.0       No      10116
# 00000789271000000          2019   459510.0      440000.0       No      10171
# 00000789262000000          2019   897530.0      939210.0      Yes       9929
# 00000789241000000          2019   772680.0      772680.0       No      10041
# 008083000G0020000          2019  1090850.0     1090850.0       No      10029
# 00000788977000000          2019   420000.0      478320.0      Yes      10111
# 00000789085000000          2019   539280.0      539280.0       No       9817
# 00808400050220000          2019   917360.0      917360.0       No      10219
# 00000789094000000          2019   426560.0      426560.0       No       9841
# 00000789354550000          2019   696320.0      696320.0       No      10105
# 00000788965000000          2019   465000.0      427500.0       No      10130
# 00000789322000000          2019   743490.0      743490.0       No      10041
# 00000788983000000          2019   750000.0      640280.0       No      10123
# 00000789007000000          2019   531120.0      531120.0       No      10142
# 00808400050200000          2019   811380.0      811380.0       No      10115
# 008083000D0030000          2019   873440.0      873440.0       No      10122
# 00000789301000000          2019   524340.0      524340.0       No       9930
# 00000789076000000          2019   440940.0      440940.0       No       9751
# 00000789256000000          2019   575850.0      575850.0       No       9949
# 00000788995000000          2019   398880.0      398880.0       No      10147
# 00000788962000000          2019   411730.0      411730.0       No      10140
# 00000789331000000          2019   510380.0      510380.0       No      10015
# 00808400050180000          2019   680000.0      720480.0      Yes      10121
# 00000789310000000          2019   631840.0      631840.0       No      10030
# 00000789319000000          2019   666270.0      666270.0       No      10051
# 00000789292000000          2019   501340.0      501340.0       No      10111
# 00000789028000000          2019   489250.0      459720.0       No      10111
# 00000789097000000          2019   545320.0      505620.0       No       9849
# 00000789013000000          2019   420000.0      420000.0       No      10130
# ...                         ...        ...           ...      ...        ...
# 00000789025000000          2019   548210.0      548210.0       No      10110
# 00000788989000000          2019   608320.0      608320.0       No      10135
# 00000788956000000          2019   435860.0      435860.0       No      10160
# 00000788992000000          2019   397000.0      433560.0      Yes      10141
# 00000789250000000          2019   568580.0      568580.0       No      10011
# 00000789022000000          2019   544950.0      381670.0       No      10114
# 00000788974000000                 N        Y         No       0.858302
# 00000789286000000                 Y        Y         No       0.889690
# 00000789283000000                 Y        Y         No       0.858437
# 00000789316000000                 N        Y         No       0.888369
#
#                    probabilityYes
# account_num
# 00000788959000000        0.144437
# 00000788971000000        0.142912
# 00000789271000000        0.142303
# 00000789262000000        0.117027
# 00000789241000000        0.124179
# 008083000G0020000        0.107507
# 00000788977000000        0.145913
# 00000789085000000        0.139595
# 00808400050220000        0.113742
# 00000789094000000        0.144724
# 00000789354550000        0.130745
# 00000788965000000        0.142830
# 00000789322000000        0.131351
# 00000788983000000        0.124181
# 00000789007000000        0.139986
# 00808400050200000        0.120941
# 008083000D0030000        0.121237
# 00000789301000000        0.141654
# 00000789076000000        0.146383
# 00000789256000000        0.140846
# 00000788995000000        0.144656
# 00000788962000000        0.143027
# 00000789331000000        0.141335
# 00808400050180000        0.131329
# 00000789310000000        0.134356
# 00000789319000000        0.133083
# 00000789292000000        0.142552
# 00000789028000000        0.140115
# 00000789097000000        0.141947
# 00000789013000000        0.145936
# ...                           ...
# 00000789025000000        0.139464
# 00000788989000000        0.133154
# 00000788956000000        0.142669
# 00000788992000000        0.144918
# 00000789250000000        0.136287
# 00000789022000000        0.137894
# 00000788998000000        0.144216
# 00000789010000000        0.143066
# 00000788953000000        0.144210
# 00000789289000000        0.140461
# 00000788986000000        0.143427
# 00000789229000000        0.111659
# 00808400050230000        0.130184
# 00000789100000000        0.144813
# 008083000G0010000        0.105468
# 00808400050190000        0.124307
# 00000789016000000        0.144122
# 00000789265000000        0.140153
# 00000789280000000        0.135847
# 00000789298000000        0.141857
# 00000789277000000        0.141134
# 00000789238000000        0.124878
# 00000789259000000        0.143816
# 00000789328000000        0.138313
# 00000789313000000        0.128972
# 00000789088000000        0.141444
# 00000788974000000        0.141698
# 00000789286000000        0.110310
# 00000789283000000        0.141563
# 00000789316000000        0.111631
#
# [79 rows x 29 columns]

# %%
# cut down the df to be a linkable table for retrieving model predictions
dfPredictions = res_2019_data[['account_num','appraisal_yr','prediction','probability1','probability2']]
# print(len(dfPredictions.account_num[0]))
# dfPredictions.head()

# %%
#push predictions to the database
#clear the existing predictions? 
# engine.execute("DROP TABLE public.predictions;")
dfPredictions.to_sql('predictions_all', con=engine, if_exists='append')
engine.execute("SELECT * FROM predictions_all LIMIT 1000").fetchall()

# %% [markdown]
# ## Random Forest Regressor

# %%
df_rfr.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000789241000000  772680.0         0                3502             1
# 00000788959000000  371470.0         0                1970             1
# 00000788971000000  506660.0         0                3582             1
# 00000789262000000  897530.0         1                3667             1
# 00000789271000000  459510.0         0                2800             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  pool_ind_N  \
# account_num
# 00000789241000000               3               1             3           1
# 00000788959000000               2               1             3           1
# 00000788971000000               3               0             4           0
# 00000789262000000               4               0             5           1
# 00000789271000000               2               0             3           0
#
#                    pool_ind_Y  sprinkler_sys_ind_N        ...         \
# account_num                                               ...
# 00000789241000000           0                    1        ...
# 00000788959000000           0                    1        ...
# 00000788971000000           1                    1        ...
# 00000789262000000           0                    0        ...
# 00000789271000000           1                    1        ...
#
#                    roof_typ_desc_HIP  roof_typ_desc_MANSARD  \
# account_num
# 00000789241000000                  1                      0
# 00000788959000000                  0                      0
# 00000788971000000                  0                      0
# 00000789262000000                  1                      0
# 00000789271000000                  1                      0
#
#                    desirability_rating_AVERAGE  desirability_rating_EXCELLENT  \
# account_num
# 00000789241000000                            0                              0
# 00000788959000000                            1                              0
# 00000788971000000                            0                              0
# 00000789262000000                            0                              0
# 00000789271000000                            0                              0
#
#                    desirability_rating_FAIR  desirability_rating_GOOD  \
# account_num
# 00000789241000000                         0                         1
# 00000788959000000                         0                         0
# 00000788971000000                         0                         1
# 00000789262000000                         0                         1
# 00000789271000000                         0                         1
#
#                    desirability_rating_VERY GOOD  bldg_class_cd_18  \
# account_num
# 00000789241000000                              0                 1
# 00000788959000000                              0                 1
# 00000788971000000                              0                 1
# 00000789262000000                              0                 0
# 00000789271000000                              0                 1
#
#                    bldg_class_cd_21  bldg_class_cd_23
# account_num
# 00000789241000000                 0                 0
# 00000788959000000                 0                 0
# 00000788971000000                 0                 0
# 00000789262000000                 1                 0
# 00000789271000000                 0                 0
#
# [5 rows x 31 columns]

# %%
# Create separate object for target variable
y = df_rfr.tot_val
# Create separate object for input features
X = df_rfr.drop('tot_val', axis=1)

# %%
# Split X and y into train and test sets: 80-20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
# train_mean = X_train.mean()
# train_std = X_train.std()

# %%
## Standardize the train data set
#X_train = (X_train - train_mean) / train_std

# %%
X_train.describe()
# Out:
#         decrease  tot_living_area_sf  num_kitchens  num_full_baths  \
# count  63.000000           63.000000          63.0       63.000000
# mean    0.158730         3305.666667           1.0        2.952381
# std     0.368359          759.081087           0.0        0.749808
# min     0.000000         1622.000000           1.0        2.000000
# 25%     0.000000         2734.500000           1.0        2.000000
# 50%     0.000000         3353.000000           1.0        3.000000
# 75%     0.000000         3723.500000           1.0        3.500000
# max     1.000000         5608.000000           1.0        4.000000
#
#        num_half_baths  num_bedrooms  pool_ind_N  pool_ind_Y  \
# count       63.000000     63.000000   63.000000   63.000000
# mean         0.761905      3.714286    0.603175    0.396825
# std          0.559789      0.682230    0.493169    0.493169
# min          0.000000      2.000000    0.000000    0.000000
# 25%          0.000000      3.000000    0.000000    0.000000
# 50%          1.000000      4.000000    1.000000    0.000000
# 75%          1.000000      4.000000    1.000000    1.000000
# max          2.000000      5.000000    1.000000    1.000000
#
#        sprinkler_sys_ind_N  sprinkler_sys_ind_Y        ...         \
# count            63.000000            63.000000        ...
# mean              0.587302             0.412698        ...
# std               0.496274             0.496274        ...
# min               0.000000             0.000000        ...
# 25%               0.000000             0.000000        ...
# 50%               1.000000             0.000000        ...
# 75%               1.000000             1.000000        ...
# max               1.000000             1.000000        ...
#
#        roof_typ_desc_HIP  roof_typ_desc_MANSARD  desirability_rating_AVERAGE  \
# count          63.000000              63.000000                    63.000000
# mean            0.365079               0.047619                     0.222222
# std             0.485320               0.214669                     0.419079
# min             0.000000               0.000000                     0.000000
# 25%             0.000000               0.000000                     0.000000
# 50%             0.000000               0.000000                     0.000000
# 75%             1.000000               0.000000                     0.000000
# max             1.000000               1.000000                     1.000000
#
#        desirability_rating_EXCELLENT  desirability_rating_FAIR  \
# count                      63.000000                 63.000000
# mean                        0.111111                  0.015873
# std                         0.316794                  0.125988
# min                         0.000000                  0.000000
# 25%                         0.000000                  0.000000
# 50%                         0.000000                  0.000000
# 75%                         0.000000                  0.000000
# max                         1.000000                  1.000000
#
#        desirability_rating_GOOD  desirability_rating_VERY GOOD  \
# count                 63.000000                      63.000000
# mean                   0.365079                       0.285714
# std                    0.485320                       0.455383
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    1.000000                       1.000000
# max                    1.000000                       1.000000
#
#        bldg_class_cd_18  bldg_class_cd_21  bldg_class_cd_23
# count         63.000000         63.000000         63.000000
# mean           0.873016          0.095238          0.031746
# std            0.335630          0.295901          0.176731
# min            0.000000          0.000000          0.000000
# 25%            1.000000          0.000000          0.000000
# 50%            1.000000          0.000000          0.000000
# 75%            1.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000
#
# [8 rows x 30 columns]

# %%
## Note: We use train_mean and train_std_dev to standardize test data set
X_test = (X_test - train_mean) / train_std

# %%
## Check for mean and std dev. - not exactly 0 and 1
X_test.describe()
# Out:
#        decrease  tot_living_area_sf  num_kitchens  num_full_baths  \
# count      16.0           16.000000          16.0       16.000000
# mean        0.0         3358.187500           1.0        3.000000
# std         0.0          772.379805           0.0        0.816497
# min         0.0         2041.000000           1.0        2.000000
# 25%         0.0         2791.750000           1.0        2.000000
# 50%         0.0         3248.000000           1.0        3.000000
# 75%         0.0         3846.750000           1.0        4.000000
# max         0.0         4564.000000           1.0        4.000000
#
#        num_half_baths  num_bedrooms  pool_ind_N  pool_ind_Y  \
# count         16.0000     16.000000   16.000000   16.000000
# mean           0.8125      3.937500    0.500000    0.500000
# std            0.7500      0.680074    0.516398    0.516398
# min            0.0000      3.000000    0.000000    0.000000
# 25%            0.0000      3.750000    0.000000    0.000000
# 50%            1.0000      4.000000    0.500000    0.500000
# 75%            1.0000      4.000000    1.000000    1.000000
# max            2.0000      5.000000    1.000000    1.000000
#
#        sprinkler_sys_ind_N  sprinkler_sys_ind_Y        ...         \
# count            16.000000            16.000000        ...
# mean              0.500000             0.500000        ...
# std               0.516398             0.516398        ...
# min               0.000000             0.000000        ...
# 25%               0.000000             0.000000        ...
# 50%               0.500000             0.500000        ...
# 75%               1.000000             1.000000        ...
# max               1.000000             1.000000        ...
#
#        roof_typ_desc_HIP  roof_typ_desc_MANSARD  desirability_rating_AVERAGE  \
# count          16.000000                   16.0                    16.000000
# mean            0.500000                    0.0                     0.312500
# std             0.516398                    0.0                     0.478714
# min             0.000000                    0.0                     0.000000
# 25%             0.000000                    0.0                     0.000000
# 50%             0.500000                    0.0                     0.000000
# 75%             1.000000                    0.0                     1.000000
# max             1.000000                    0.0                     1.000000
#
#        desirability_rating_EXCELLENT  desirability_rating_FAIR  \
# count                      16.000000                      16.0
# mean                        0.187500                       0.0
# std                         0.403113                       0.0
# min                         0.000000                       0.0
# 25%                         0.000000                       0.0
# 50%                         0.000000                       0.0
# 75%                         0.000000                       0.0
# max                         1.000000                       0.0
#
#        desirability_rating_GOOD  desirability_rating_VERY GOOD  \
# count                 16.000000                      16.000000
# mean                   0.312500                       0.187500
# std                    0.478714                       0.403113
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    1.000000                       0.000000
# max                    1.000000                       1.000000
#
#        bldg_class_cd_18  bldg_class_cd_21  bldg_class_cd_23
# count         16.000000         16.000000           16.0000
# mean           0.812500          0.125000            0.0625
# std            0.403113          0.341565            0.2500
# min            0.000000          0.000000            0.0000
# 25%            1.000000          0.000000            0.0000
# 50%            1.000000          0.000000            0.0000
# 75%            1.000000          0.000000            0.0000
# max            1.000000          1.000000            1.0000
#
# [8 rows x 30 columns]

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (63, 30) (16, 30) (63,) (16,)

# %%
## Reference for random search on random forest
## https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
tuned_params = {'n_estimators': [100, 200, 300, 400, 500], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
model = RandomizedSearchCV(RandomForestRegressor(), tuned_params, n_iter=20, scoring = 'neg_mean_absolute_error', cv=5, n_jobs=-1)
model.fit(X_train, y_train)
## This takes around 15 minutes
# Out:
# D:\Workspace\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=20, n_jobs=-1,
#           param_distributions={'n_estimators': [100, 200, 300, 400, 500], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring='neg_mean_absolute_error',
#           verbose=0)

# %%
model.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
## Predict Train results
y_train_pred = model.predict(X_train)

# %%
## Predict Test results
y_pred = model.predict(X_test)

# %%
print("Train Results for Random Forest Regression:")
print("*******************************")
print("Root mean squared error: ", sqrt(mse(y_train.values, y_train_pred)))
print("R-squared: ", rs(y_train.values, y_train_pred))
print("Mean Absolute Error: ", mae(y_train.values, y_train_pred))
# Out:
# Train Results for Random Forest Regression:
# *******************************
# Root mean squared error:  41345.727673042325
# R-squared:  0.9531575306670976
# Mean Absolute Error:  28356.960952380945

# %%
print("Test Results for Random Forest Regression:")
print("*******************************")
print("Root mean squared error: ", sqrt(mse(y_test, y_pred)))
print("R-squared: ", rs(y_test, y_pred))
print("Mean Absolute Error: ", mae(y_test, y_pred))
# Out:
# Test Results for Random Forest Regression:
# *******************************
# Root mean squared error:  71386.44564217023
# R-squared:  0.8350931678321393
# Mean Absolute Error:  53587.88625000001

# %%
## Building the model again with the best hyperparameters
model = RandomForestRegressor(n_estimators=200, min_samples_split=10, min_samples_leaf=2)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
indices = np.argsort(-model.feature_importances_)
print("The features in order of importance are:")
print(50*'-')
for feature in X.columns[indices]:
    print(feature)
# Out:
# The features in order of importance are:
# --------------------------------------------------
# tot_living_area_sf
# bldg_class_cd_18
# bldg_class_cd_21
# roof_typ_desc_HIP
# num_full_baths
# num_half_baths
# desirability_rating_EXCELLENT
# desirability_rating_AVERAGE
# desirability_rating_GOOD
# pool_ind_Y
# num_bedrooms
# bldg_class_cd_23
# decrease
# desirability_rating_VERY GOOD
# roof_typ_desc_GABLE
# pool_ind_N
# foundation_typ_desc_PIER AND BEAM
# sprinkler_sys_ind_N
# sprinkler_sys_ind_Y
# foundation_typ_desc_SLAB
# ac_typ_desc_CENTRAL FULL
# num_kitchens
# desirability_rating_FAIR
# roof_typ_desc_MANSARD
# ext_wall_desc_STUCCO
# ext_wall_desc_STONE VENEER
# ext_wall_desc_FRAME
# ext_wall_desc_BRICK VENEER
# heating_typ_desc_CENTRAL FULL
# ac_typ_desc_UNASSIGNED
