# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import pandas as pd 
import numpy as np
import os
import string
from math import sqrt
from config import u, p

# %%
# Evaluation Metrics
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as rs
from sklearn.metrics import mean_absolute_error as mae

# to split train and test set
from sklearn.model_selection import train_test_split

# to perform hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

#models
from sklearn.linear_model import Ridge  # Linear Regression + L2 regularization
from sklearn.linear_model import Lasso  # Linear Regression + L1 regularization
from sklearn.svm import SVR # Support Vector Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.tree import DecisionTreeRegressor

# %%
# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# to save the final model on disk
from sklearn.externals import joblib

# %%
from psycopg2.extensions import register_adapter, AsIs
def adapt_numpy_int64(numpy_int64):
  return AsIs(numpy_int64)
register_adapter(np.int64, adapt_numpy_int64)

# %% [markdown]
# ## Connect to DB: Create sample data that joins Acocunt Info, Appraisal Data, & Res_Adl

# %%
database_path = f'postgres://{u}:{p}@database1.cpwzlmglu2fg.us-east-2.rds.amazonaws.com/proptax'

# %%
# Create Engine
engine = create_engine(database_path)
conn = engine.connect()

# %%
# The ORM’s “handle” to the database is the Session.
session = Session(engine)

# %% [markdown]
# ### Sample 2019

# %%
query_one = "select ai.account_num, ai.appraisal_yr, aay.tot_val, aay.prev_mkt_val, CASE WHEN aay.tot_val < aay.prev_mkt_val THEN 1 ELSE 0 END as Decrease, \
       street_num, street_half_num, full_street_name, property_city, property_zipcode, mapsco, desirability_rating, bldg_class_cd, tot_living_area_sf, foundation_typ_desc, heating_typ_desc, ac_typ_desc, ext_wall_desc, roof_typ_desc, num_fireplaces, num_kitchens, num_full_baths, num_half_baths, num_wet_bars, num_bedrooms, sprinkler_sys_ind, pool_ind, \
       l.area_size \
        from account_info_2019 as ai \
        INNER JOIN account_apprl_year_2019 as aay on ai.account_num = aay.account_num \
        INNER JOIN res_detail_2019 as rd on aay.account_num = rd.account_num \
        INNER JOIN land as l on ai.account_num = l.account_num\
        where ai.division_cd = 'RES' \
        and ai.account_num not in (select account_num from predicted_values pv) \
        ORDER BY RANDOM() \
        LIMIT 100000"
        

res_2019_data = pd.read_sql(query_one, conn).set_index('account_num')

# %% [markdown]
# ## Explore Sample Data

# %%
# 2019
res_2019_data.head(10)
# Out:
#                    appraisal_yr   tot_val  prev_mkt_val  decrease street_num  \
# account_num
# 32077940010010000          2019  783610.0      738580.0         0       1319
# 65025577510390000          2019  459490.0      379450.0         0        130
# 00000382393000000          2019  214060.0      189240.0         0      11354
# 00000119512000000          2019  834720.0      266040.0         0       4407
# 00000186604000000          2019  363110.0      363110.0         0       5608
# 00000793951440000          2019  511730.0      511730.0         0       7322
# 48004590090090000          2019  245100.0      245100.0         0       4805
# 280116000C0240000          2019  240140.0      240140.0         0        860
# 007594000B0250000          2019  145860.0      129420.0         0        152
# 26079500000040000          2019   91520.0      111520.0         1        120
#
#                   street_half_num   full_street_name  \
# account_num
# 32077940010010000                       N TRAVIS CIR
# 65025577510390000                     WAGON WHEEL LN
# 00000382393000000                        FLAMINGO LN
# 00000119512000000                           DEERE ST
# 00000186604000000                         WILLIS AVE
# 00000793951440000                     CRAIGSHIRE AVE
# 48004590090090000                       PEACHTREE LN
# 280116000C0240000                      RIDGECREST RD
# 007594000B0250000                  CLIFF HEIGHTS CIR
# 26079500000040000                           W AVE D
#
#                                property_city property_zipcode          mapsco  \
# account_num
# 32077940010010000                     IRVING        750386257  21A-Z (DALLAS)
# 65025577510390000                    NO TOWN            75098  10A-V (DALLAS)
# 00000382393000000                     DALLAS        752181903   38-C (DALLAS)
# 00000119512000000                     DALLAS        752043609   35-Z (DALLAS)
# 00000186604000000                     DALLAS        752066441   36-S (DALLAS)
# 00000793951440000                     DALLAS        752314748   26-R (DALLAS)
# 48004590090090000                     SACHSE        750484117   10-W (DALLAS)
# 280116000C0240000  GRAND PRAIRIE (DALLAS CO)        750521248   61-U (DALLAS)
# 007594000B0250000                     DALLAS        752415333   64-Z (DALLAS)
# 26079500000040000        GARLAND (DALLAS CO)        750407114  19A-W (DALLAS)
#
#                      ...     roof_typ_desc num_fireplaces  num_kitchens  \
# account_num          ...
# 32077940010010000    ...             GABLE              1             1
# 65025577510390000    ...               HIP              1             1
# 00000382393000000    ...             GABLE              1             1
# 00000119512000000    ...             GABLE              0            10
# 00000186604000000    ...             GABLE              0             1
# 00000793951440000    ...               HIP              1             1
# 48004590090090000    ...             GABLE              1             1
# 280116000C0240000    ...               HIP              1             1
# 007594000B0250000    ...               HIP              0             1
# 26079500000040000    ...             GABLE              0             1
#
#                   num_full_baths num_half_baths num_wet_bars num_bedrooms  \
# account_num
# 32077940010010000              3              1            2            4
# 65025577510390000              3              1            0            4
# 00000382393000000              2              0            0            3
# 00000119512000000             20              0            0           20
# 00000186604000000              2              0            0            3
# 00000793951440000              3              0            1            4
# 48004590090090000              2              1            0            4
# 280116000C0240000              2              0            0            3
# 007594000B0250000              2              1            0            3
# 26079500000040000              3              0            0            3
#
#                   sprinkler_sys_ind  pool_ind  area_size
# account_num
# 32077940010010000                 Y         Y   28731.00
# 65025577510390000                 N         N       2.51
# 00000382393000000                 N         N    8040.00
# 00000119512000000                 N         N    8868.00
# 00000186604000000                 N         N    7800.00
# 00000793951440000                 N         Y    8639.00
# 48004590090090000                 N         N   12843.00
# 280116000C0240000                 Y         N       0.00
# 007594000B0250000                 N         N       0.00
# 26079500000040000                 N         N   18290.00
#
# [10 rows x 27 columns]

# %%
res_2019_data.shape

# %%
res_2019_data.columns

# %%
res_2019_data.dtypes

# %%
# Plot histogram grid
res_2019_data.hist(figsize=(24,24), xrot=-45) ## Display the labels rotated by 45 degress

# Clear the text "residue"
plt.show()

# %%
# PLot Desirablilty
plt.figure(figsize=(8,8))
sns.countplot(y='desirability_rating', data=res_2019_data)

# %%
# Drop Null Values 
drop_res_2019_data = res_2019_data.dropna(how="all")

# %%
drop_res_2019_data.head()
# Out:
#                    appraisal_yr   tot_val  prev_mkt_val  decrease street_num  \
# account_num
# 32077940010010000          2019  783610.0      738580.0         0       1319
# 65025577510390000          2019  459490.0      379450.0         0        130
# 00000382393000000          2019  214060.0      189240.0         0      11354
# 00000119512000000          2019  834720.0      266040.0         0       4407
# 00000186604000000          2019  363110.0      363110.0         0       5608
#
#                   street_half_num full_street_name property_city  \
# account_num
# 32077940010010000                     N TRAVIS CIR        IRVING
# 65025577510390000                   WAGON WHEEL LN       NO TOWN
# 00000382393000000                      FLAMINGO LN        DALLAS
# 00000119512000000                         DEERE ST        DALLAS
# 00000186604000000                       WILLIS AVE        DALLAS
#
#                   property_zipcode          mapsco    ...     roof_typ_desc  \
# account_num                                           ...
# 32077940010010000        750386257  21A-Z (DALLAS)    ...             GABLE
# 65025577510390000            75098  10A-V (DALLAS)    ...               HIP
# 00000382393000000        752181903   38-C (DALLAS)    ...             GABLE
# 00000119512000000        752043609   35-Z (DALLAS)    ...             GABLE
# 00000186604000000        752066441   36-S (DALLAS)    ...             GABLE
#
#                   num_fireplaces  num_kitchens num_full_baths num_half_baths  \
# account_num
# 32077940010010000              1             1              3              1
# 65025577510390000              1             1              3              1
# 00000382393000000              1             1              2              0
# 00000119512000000              0            10             20              0
# 00000186604000000              0             1              2              0
#
#                   num_wet_bars num_bedrooms sprinkler_sys_ind  pool_ind  \
# account_num
# 32077940010010000            2            4                 Y         Y
# 65025577510390000            0            4                 N         N
# 00000382393000000            0            3                 N         N
# 00000119512000000            0           20                 N         N
# 00000186604000000            0            3                 N         N
#
#                    area_size
# account_num
# 32077940010010000   28731.00
# 65025577510390000       2.51
# 00000382393000000    8040.00
# 00000119512000000    8868.00
# 00000186604000000    7800.00
#
# [5 rows x 27 columns]

# %%
#drop_res_2019_data.loc['00000788983000000']

# %%
plt.figure(figsize=(16,16))
sns.heatmap(drop_res_2019_data.corr())

# %%
# Create a DF using only existing interger columns 
int_df = drop_res_2019_data[['tot_val', 'decrease', 'tot_living_area_sf', 'num_kitchens', 'num_full_baths', 'num_half_baths', 'num_bedrooms', 'area_size']]
int_df.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 32077940010010000  783610.0         0                3500             1
# 65025577510390000  459490.0         0                2269             1
# 00000382393000000  214060.0         0                1648             1
# 00000119512000000  834720.0         0                9776            10
# 00000186604000000  363110.0         0                1590             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  area_size
# account_num
# 32077940010010000               3               1             4   28731.00
# 65025577510390000               3               1             4       2.51
# 00000382393000000               2               0             3    8040.00
# 00000119512000000              20               0            20    8868.00
# 00000186604000000               2               0             3    7800.00

# %%
int_df.columns
# Out:
# Index(['tot_val', 'decrease', 'tot_living_area_sf', 'num_kitchens',
#        'num_full_baths', 'num_half_baths', 'num_bedrooms', 'area_size'],
#       dtype='object')

# %%
# Create a DF using only existing object columns 
object_df = drop_res_2019_data[['pool_ind', 'sprinkler_sys_ind', 'foundation_typ_desc', 'heating_typ_desc', 'ac_typ_desc', 'ext_wall_desc', 'roof_typ_desc', 'desirability_rating', 'bldg_class_cd','mapsco']]
object_df.head()
# Out:
#                   pool_ind sprinkler_sys_ind foundation_typ_desc  \
# account_num
# 32077940010010000        Y                 Y       PIER AND BEAM
# 65025577510390000        N                 N                SLAB
# 00000382393000000        N                 N       PIER AND BEAM
# 00000119512000000        N                 N                SLAB
# 00000186604000000        N                 N                POST
#
#                   heating_typ_desc   ac_typ_desc ext_wall_desc roof_typ_desc  \
# account_num
# 32077940010010000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER         GABLE
# 65025577510390000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER           HIP
# 00000382393000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER         GABLE
# 00000119512000000     CENTRAL FULL  CENTRAL FULL  BRICK VENEER         GABLE
# 00000186604000000     CENTRAL FULL  CENTRAL FULL         FRAME         GABLE
#
#                            desirability_rating bldg_class_cd          mapsco
# account_num
# 32077940010010000                         GOOD            21  21A-Z (DALLAS)
# 65025577510390000                    EXCELLENT            18  10A-V (DALLAS)
# 00000382393000000                         FAIR            13   38-C (DALLAS)
# 00000119512000000  MANUALLY ENTER DEPRECIATION      TOWNHOME   35-Z (DALLAS)
# 00000186604000000                         FAIR            04   36-S (DALLAS)

# %%
object_df.columns

# %% [markdown]
# ### Get Dummies

# %%
# Dummify object dataframe 
dummy_df = pd.get_dummies(object_df)
dummy_df.head()
# Out:
#                    pool_ind_N  pool_ind_Y  sprinkler_sys_ind_N  \
# account_num
# 32077940010010000           0           1                    0
# 65025577510390000           1           0                    1
# 00000382393000000           1           0                    1
# 00000119512000000           1           0                    1
# 00000186604000000           1           0                    1
#
#                    sprinkler_sys_ind_Y  foundation_typ_desc_BLOCK  \
# account_num
# 32077940010010000                    1                          0
# 65025577510390000                    0                          0
# 00000382393000000                    0                          0
# 00000119512000000                    0                          0
# 00000186604000000                    0                          0
#
#                    foundation_typ_desc_BRICK  \
# account_num
# 32077940010010000                          0
# 65025577510390000                          0
# 00000382393000000                          0
# 00000119512000000                          0
# 00000186604000000                          0
#
#                    foundation_typ_desc_FOUNDATION SUPPORT  \
# account_num
# 32077940010010000                                       0
# 65025577510390000                                       0
# 00000382393000000                                       0
# 00000119512000000                                       0
# 00000186604000000                                       0
#
#                    foundation_typ_desc_GIRDER ON THE GROUND  \
# account_num
# 32077940010010000                                         0
# 65025577510390000                                         0
# 00000382393000000                                         0
# 00000119512000000                                         0
# 00000186604000000                                         0
#
#                    foundation_typ_desc_GRADE AND INTERIOR BEAM  \
# account_num
# 32077940010010000                                            0
# 65025577510390000                                            0
# 00000382393000000                                            0
# 00000119512000000                                            0
# 00000186604000000                                            0
#
#                    foundation_typ_desc_IRON PIPE          ...           \
# account_num                                               ...
# 32077940010010000                              0          ...
# 65025577510390000                              0          ...
# 00000382393000000                              0          ...
# 00000119512000000                              0          ...
# 00000186604000000                              0          ...
#
#                    mapsco_9A-Q (DALLAS)  mapsco_9A-R (DALLAS)  \
# account_num
# 32077940010010000                     0                     0
# 65025577510390000                     0                     0
# 00000382393000000                     0                     0
# 00000119512000000                     0                     0
# 00000186604000000                     0                     0
#
#                    mapsco_9A-S (DALLAS)  mapsco_9A-T (DALLAS)  \
# account_num
# 32077940010010000                     0                     0
# 65025577510390000                     0                     0
# 00000382393000000                     0                     0
# 00000119512000000                     0                     0
# 00000186604000000                     0                     0
#
#                    mapsco_9A-U (DALLAS)  mapsco_9A-V (DALLAS)  \
# account_num
# 32077940010010000                     0                     0
# 65025577510390000                     0                     0
# 00000382393000000                     0                     0
# 00000119512000000                     0                     0
# 00000186604000000                     0                     0
#
#                    mapsco_9A-W (DALLAS)  mapsco_9A-X (DALLAS)  \
# account_num
# 32077940010010000                     0                     0
# 65025577510390000                     0                     0
# 00000382393000000                     0                     0
# 00000119512000000                     0                     0
# 00000186604000000                     0                     0
#
#                    mapsco_9A-Y (DALLAS)  mapsco_9A-Z (DALLAS)
# account_num
# 32077940010010000                     0                     0
# 65025577510390000                     0                     0
# 00000382393000000                     0                     0
# 00000119512000000                     0                     0
# 00000186604000000                     0                     0
#
# [5 rows x 2276 columns]

# %%
dummy_df.columns

# %%
#dummy_df.dtypes #takes forever on the full dataset

# %% [markdown]
# ### Create the Clean DF by merging int_df and dummy_df

# %%
clean_df = pd.merge(int_df, dummy_df, right_index=True, left_index=True, how="inner")
clean_df = clean_df.drop('pool_ind_N',axis=1)
clean_df = clean_df.drop('sprinkler_sys_ind_N',axis=1)
clean_df.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000107680180000  379690.0         0                1890             1
# 00000107680200000  395690.0         0                2685             1
# 00000107680440000  324840.0         0                1577             1
# 00000107680460000  383320.0         0                2258             1
# 00000107680480000  364910.0         0                2047             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  area_size  \
# account_num
# 00000107680180000               2               0             2     3397.0
# 00000107680200000               2               1             3     3397.0
# 00000107680440000               2               0             2     3655.0
# 00000107680460000               2               1             2     3655.0
# 00000107680480000               2               1             2     3655.0
#
#                    pool_ind_Y  sprinkler_sys_ind_Y          ...           \
# account_num                                                 ...
# 00000107680180000           0                    1          ...
# 00000107680200000           0                    1          ...
# 00000107680440000           0                    1          ...
# 00000107680460000           0                    1          ...
# 00000107680480000           0                    1          ...
#
#                    mapsco_9A-Q (DALLAS)  mapsco_9A-R (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-S (DALLAS)  mapsco_9A-T (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-U (DALLAS)  mapsco_9A-V (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-W (DALLAS)  mapsco_9A-X (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-Y (DALLAS)  mapsco_9A-Z (DALLAS)
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
# [5 rows x 2282 columns]

# %%
clean_df.describe()

# %%
clean_df = clean_df.dropna(how="any")

# %%
clean_df.shape

# %% [markdown]
# ### Create Dataframes to use with models

# %%
df_rfr = clean_df
df_rfr.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000107680180000  379690.0         0                1890             1
# 00000107680200000  395690.0         0                2685             1
# 00000107680440000  324840.0         0                1577             1
# 00000107680460000  383320.0         0                2258             1
# 00000107680480000  364910.0         0                2047             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  area_size  \
# account_num
# 00000107680180000               2               0             2     3397.0
# 00000107680200000               2               1             3     3397.0
# 00000107680440000               2               0             2     3655.0
# 00000107680460000               2               1             2     3655.0
# 00000107680480000               2               1             2     3655.0
#
#                    pool_ind_Y  sprinkler_sys_ind_Y          ...           \
# account_num                                                 ...
# 00000107680180000           0                    1          ...
# 00000107680200000           0                    1          ...
# 00000107680440000           0                    1          ...
# 00000107680460000           0                    1          ...
# 00000107680480000           0                    1          ...
#
#                    mapsco_9A-Q (DALLAS)  mapsco_9A-R (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-S (DALLAS)  mapsco_9A-T (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-U (DALLAS)  mapsco_9A-V (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-W (DALLAS)  mapsco_9A-X (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-Y (DALLAS)  mapsco_9A-Z (DALLAS)
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
# [5 rows x 2282 columns]

# %% [markdown]
# <h1><center>Machine Learning Models</center></h1>

# %% [markdown]
# ## Random Forest Regressor

# %%
df_rfr.head()
# Out:
#                     tot_val  decrease  tot_living_area_sf  num_kitchens  \
# account_num
# 00000107680180000  379690.0         0                1890             1
# 00000107680200000  395690.0         0                2685             1
# 00000107680440000  324840.0         0                1577             1
# 00000107680460000  383320.0         0                2258             1
# 00000107680480000  364910.0         0                2047             1
#
#                    num_full_baths  num_half_baths  num_bedrooms  area_size  \
# account_num
# 00000107680180000               2               0             2     3397.0
# 00000107680200000               2               1             3     3397.0
# 00000107680440000               2               0             2     3655.0
# 00000107680460000               2               1             2     3655.0
# 00000107680480000               2               1             2     3655.0
#
#                    pool_ind_Y  sprinkler_sys_ind_Y          ...           \
# account_num                                                 ...
# 00000107680180000           0                    1          ...
# 00000107680200000           0                    1          ...
# 00000107680440000           0                    1          ...
# 00000107680460000           0                    1          ...
# 00000107680480000           0                    1          ...
#
#                    mapsco_9A-Q (DALLAS)  mapsco_9A-R (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-S (DALLAS)  mapsco_9A-T (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-U (DALLAS)  mapsco_9A-V (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-W (DALLAS)  mapsco_9A-X (DALLAS)  \
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
#                    mapsco_9A-Y (DALLAS)  mapsco_9A-Z (DALLAS)
# account_num
# 00000107680180000                     0                     0
# 00000107680200000                     0                     0
# 00000107680440000                     0                     0
# 00000107680460000                     0                     0
# 00000107680480000                     0                     0
#
# [5 rows x 2282 columns]

# %%
# Create separate object for target variable
y = df_rfr.tot_val
# Create separate object for input features
X = df_rfr.drop('tot_val', axis=1)

# %%
# Split X and y into train and test sets: 70-30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# train_mean = X_train.mean()
# train_std = X_train.std()

# %%
## Standardize the train data set
#X_train = (X_train - train_mean) / train_std

# %%
#X_train.describe()

# %%
## Note: We use train_mean and train_std_dev to standardize test data set
#X_test = (X_test - train_mean) / train_std

# %%
## Check for mean and std dev. - not exactly 0 and 1
#X_test.describe()

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (70070, 2281) (30030, 2281) (70070,) (30030,)

# %%
# ## Reference for random search on random forest
# ## https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
# tuned_params = {'n_estimators': [100, 200, 300, 400, 500], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
# model = RandomizedSearchCV(RandomForestRegressor(), tuned_params, n_iter=20, scoring = 'neg_mean_absolute_error', cv=5, n_jobs=6)
# model.fit(X_train, y_train)
# ## This takes around 15 minutes

# %%
## Building the model again with the best hyperparameters
model = RandomForestRegressor(n_estimators=200, min_samples_split=10, min_samples_leaf=2, n_jobs=3)
model.fit(X_train, y_train)

# %%
model.best_estimator_

# %%
## Predict Train results
y_train_pred = model.predict(X_train)

# %%
## Predict Test results
y_test_pred = model.predict(X_test)

# %%
#y_test_pred

# %%
print("Train Results for Random Forest Regression:")
print("*******************************")
print("Root mean squared error: ", sqrt(mse(y_train.values, y_train_pred)))
print("R-squared: ", rs(y_train.values, y_train_pred))
print("Mean Absolute Error: ", mae(y_train.values, y_train_pred))

# %%
print("Test Results for Random Forest Regression:")
print("*******************************")
print("Root mean squared error: ", sqrt(mse(y_test, y_test_pred)))
print("R-squared: ", rs(y_test, y_test_pred))
print("Mean Absolute Error: ", mae(y_test, y_test_pred))

# %%
indices = np.argsort(-model.feature_importances_)
print("The features in order of importance are:")
print(50*'-')
for feature in X.columns[indices]:
    print(feature)

# %%
model.fit(X_train, y_train)
with open('rfr_prop_tax.model', 'wb') as f:
       joblib.dump(model, 'rfr_prop_tax.model')

# %% [markdown]
# ## Run Saved Model

# %%
loaded_model = joblib.load('rfr_prop_tax.model')
result = loaded_model.score(X, y)
print(result)

# %%
loaded_model.fit(X, y)

# %%
tot_val_pred = model.predict(X)

# %%
#tot_val_pred

# %%
df_rfr['tot_val_pred'] = tot_val_pred.round(decimals=0, out=None)

# %%
df_rfr[['tot_val', 'tot_val_pred']].head(100)

# %%
# #empty existing table
# conn.execute('truncate table predicted_values')

# %%
#insert predicted values in database
df_rfr[['tot_val', 'tot_val_pred']].to_sql('predicted_values', conn, if_exists="append")
